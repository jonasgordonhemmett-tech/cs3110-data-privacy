# %% [markdown]
# # CS 3110/5110: Data Privacy
# ## Homework 3

# %%
# Load the data and libraries
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from unittest.mock import patch

def laplace_mech(v, sensitivity, epsilon):
    return v + np.random.laplace(loc=0, scale=sensitivity / epsilon)

adult = pd.read_csv('https://github.com/jnear/cs3110-data-privacy/raw/main/homework/adult_with_pii.csv')
adult = adult.dropna()

# %%
adult.head()
# Out:
#                Name        DOB          SSN    Zip  Age         Workclass  \
# 0  Karrie Trusslove   9/7/1967  732-14-6110  64152   39         State-gov
# 1  Brandise Tripony   6/7/1988  150-19-2766  61523   50  Self-emp-not-inc
# 2     Brenn McNeely   8/6/1991  725-59-9860  95668   38           Private
# 3       Dorry Poter   4/6/2009  659-57-4974  25503   53           Private
# 4       Dick Honnan  9/16/1951  220-93-3811  75387   28           Private
#
#    fnlwgt  Education  Education-Num      Marital Status         Occupation  \
# 0   77516  Bachelors             13       Never-married       Adm-clerical
# 1   83311  Bachelors             13  Married-civ-spouse    Exec-managerial
# 2  215646    HS-grad              9            Divorced  Handlers-cleaners
# 3  234721       11th              7  Married-civ-spouse  Handlers-cleaners
# 4  338409  Bachelors             13  Married-civ-spouse     Prof-specialty
#
#     Relationship   Race     Sex  Capital Gain  Capital Loss  Hours per week  \
# 0  Not-in-family  White    Male          2174             0              40
# 1        Husband  White    Male             0             0              13
# 2  Not-in-family  White    Male             0             0              40
# 3        Husband  Black    Male             0             0              40
# 4           Wife  Black  Female             0             0              40
#
#          Country Target
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States  <=50K
# 3  United-States  <=50K
# 4           Cuba  <=50K

# %% [markdown]
# ## Question 1 (10 points)
#
# Write code to answer the query: "how many participants have never been married?"
#
# *Hint*: filter the `adult_data` dataframe to contain only participants who were never married, then return the  `len` of the filtered dataframe.

# %%
def query1():
    return len(adult[adult['Marital Status'] == 'Never-married'])
query1()
# Out:
# 9726

# %%
# TEST CASE for question 1
assert query1() == 9726

# %% [markdown]
# ## Question 2 (5 points)
#
# In 2-5 sentences, answer the following:
# - What is the sensitivity of `query1`, and why?

# %% [markdown]
# The sensitivity of query1 is 1. It is 1 because adding or removing one person would change the result of the query by 1

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 3 (10 points)
#
# Use the implementation of `laplace_mech` to produce a differentially private answer to `query1`, with `epsilon = 0.1`.

# %%
def dp_query1(epsilon):
    answer = query1()
    noise = np.random.laplace(loc=0, scale=1/epsilon)
    answer += noise
    return answer

dp_query1(0.1)
# Out:
# 9718.721588600267

# %%
# TEST CASE for question 3
dp_results = [dp_query1(0.1) for _ in range(100)]
spec = [np.random.laplace(loc=9726, scale=1/0.1) for _ in range(100)]
assert stats.wasserstein_distance(dp_results, spec) < 10

# %% [markdown]
# ## Question 4 (10 points)
#
# The `pct_error` function, defined below, returns the percent relative error between an original query result and a differentially private result for the same query.
#
# Implement a function `graph_error1` that:
#
# - Calculates 1000 differentially private answers to `dp_query1`
# - Calculates the percent error for each one of these answers against the original (non-private) answer
# - Graphs the distribution of errors using a histogram
#
# *Hint*: use `plt.hist(..., bins=20)`.
#
# The given code will use your function to plot errors for `epsilon=0.1` and `epsilon=1.0`.

# %%
def pct_error(orig, priv):
    return np.abs(orig - priv)/orig * 100.0

# %%
def graph_error1(epsilon):
    answers_ndp = pd.Series(query1() for _ in range(1000))
    answers_dp = pd.Series(dp_query1(epsilon) for _ in range(1000))
    answers_diff = answers_ndp - answers_dp
    print(answers_diff)

graph_error1(0.1)
graph_error1(1.0)
# Out:
# 0      10.552175
# 1      13.737748
# 2      -5.057465
# 3      -2.900459
# 4       3.640157
#          ...
# 995    -2.459731
# 996    -8.400571
# 997     6.694738
# 998    -6.418613
# 999    -4.177427
# Length: 1000, dtype: float64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 8
#       4     answers_diff = answers_ndp - answers_dp
#       5     print(answers_diff)
#       6
#       7 graph_error1(0.1)
# ----> 8 graph_error1(1.0)
#
# Cell In[17], line 3, in graph_error1(epsilon)
#       1 def graph_error1(epsilon):
#       2     answers_ndp = pd.Series(query1() for _ in range(1000))
# ----> 3     answers_dp = pd.Series(dp_query1(epsilon) for _ in range(1000))
#       4     answers_diff = answers_ndp - answers_dp
#       5     print(answers_diff)
#
# File ~\Documents\cs3110-data-privacy\.venv\Lib\site-packages\pandas\core\series.py:493, in Series.__init__(self, data, index, dtype, name, copy)
#     491     pass
#     492 else:
# --> 493     data = com.maybe_iterable_to_list(data)
#     494     if is_list_like(data) and not len(data) and dtype is None:
#     495         # GH 29405: Pre-2.0, this defaulted to float.
#     496         dtype = np.dtype(object)
#
# File ~\Documents\cs3110-data-privacy\.venv\Lib\site-packages\pandas\core\common.py:310, in maybe_iterable_to_list(obj)
#     306 """
#     307 If obj is Iterable but not list-like, consume into list.
#     308 """
#     309 if isinstance(obj, abc.Iterable) and not isinstance(obj, abc.Sized):
# --> 310     return list(obj)
#     311 obj = cast(Collection, obj)
#     312 return obj
#
# Cell In[17], line 3, in graph_error1.<locals>.<genexpr>(.0)
# ----> 3 def graph_error1(epsilon):
#       4     answers_ndp = pd.Series(query1() for _ in range(1000))
#       5     answers_dp = pd.Series(dp_query1(epsilon) for _ in range(1000))
#       6     answers_diff = answers_ndp - answers_dp
#
# Cell In[8], line 2, in dp_query1(epsilon)
#       1 def dp_query1(epsilon):
# ----> 2     answer = query1()
#       3     noise = np.random.laplace(loc=0, scale=1/epsilon)
#       4     answer += noise
#       5     return answer
#
# Cell In[6], line 2, in query1()
#       1 def query1():
# ----> 2     return len(adult[adult['Marital Status'] == 'Never-married'])
#
# File ~\Documents\cs3110-data-privacy\.venv\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\Documents\cs3110-data-privacy\.venv\Lib\site-packages\pandas\core\arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File ~\Documents\cs3110-data-privacy\.venv\Lib\site-packages\pandas\core\series.py:6735, in Series._cmp_method(self, other, op)
#    6732 lvalues = self._values
#    6733 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6735 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6737 return self._construct_result(res_values, name=res_name, other=other)
#
# File ~\Documents\cs3110-data-privacy\.venv\Lib\site-packages\pandas\core\ops\array_ops.py:341, in comparison_op(left, right, op)
#     332         raise ValueError(
#     333             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     334         )
#     336 if should_extension_dispatch(lvalues, rvalues) or (
#     337     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     338     and lvalues.dtype != object
#     339 ):
#     340     # Call the method on lvalues
# --> 341     res_values = op(lvalues, rvalues)
#     343 # TODO: but not pd.NA?
#     344 elif (is_scalar(rvalues) or rvalues_is_zerodim) and isna(rvalues):
#     345     # numpy does not like comparisons vs None
#
# File ~\Documents\cs3110-data-privacy\.venv\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\Documents\cs3110-data-privacy\.venv\Lib\site-packages\pandas\core\arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File ~\Documents\cs3110-data-privacy\.venv\Lib\site-packages\pandas\core\arrays\string_.py:1239, in StringArray._cmp_method(self, other, op)
#    1236     return self._from_backing_data(result)
#    1237 else:
#    1238     # logical
# -> 1239     result = np.zeros(len(self._ndarray), dtype="bool")
#    1240     result[valid] = op(self._ndarray[valid], other)
#    1241     res_arr = BooleanArray(result, mask)
#
# KeyboardInterrupt:

# %%
error_spec = 100.0 * np.abs(np.random.laplace(loc=0, scale=1, size=1000)) / query1()

with patch('matplotlib.pyplot.hist') as mock_hist:
    graph_error1(1.0)
    
args, kwargs = mock_hist.call_args
assert stats.wasserstein_distance(error_spec, args[0]) < 0.001

# %% [markdown]
# ## Question 5 (10 points)
#
# In 2-5 sentences, answer the following:
#
# - How does the histogram of relative errors for $\epsilon = 0.1$ differ from the one for $\epsilon = 1.0$?
# - What do the two histograms tell you about the effect of $\epsilon$ on relative error?
#
# *Hint*: Pay close attention to which color represents which value of $\epsilon$!

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 6 (10 points)
#
# Consider `query2`, which asks how many people in the dataset are over the age of 60.

# %%
def query2():
    return len(adult[adult['Age'] > 60])

# %% [markdown]
# Implement `dp_query2`, a differentially private version of `query2` (as in question 3), and `graph_error2`, which graphs relative error for `dp_query2` (as in question 4).

# %%
def dp_query2(epsilon):
    # YOUR CODE HERE
    raise NotImplementedError()

def graph_error2(epsilon):
    # YOUR CODE HERE
    raise NotImplementedError()

graph_error2(1.0)
graph_error1(1.0) # we plot both errors for query 1 and query 2 at the same epsilon, to compare

# %%
error_spec = 100.0 * np.abs(np.random.laplace(loc=0, scale=1, size=1000)) / query2()

with patch('matplotlib.pyplot.hist') as mock_hist:
    graph_error2(1.0)
    
args, kwargs = mock_hist.call_args
assert stats.wasserstein_distance(error_spec, args[0]) < 0.01

# %% [markdown]
# ## Question 7 (10 points)
#
# In 2-5 sentences, answer the following:
#
# - Given the graph from question 6, how does relative error differ between `dp_query1` and `dp_query2` for the same value of $\epsilon$?
# - What property of the query causes the difference in relative errors between `dp_query1` and `dp_query2`?

# %% [markdown]
# YOUR ANSWER HERE
